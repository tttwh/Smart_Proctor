# %%
# !pip install roboflow ultralytics

from roboflow import Roboflow
rf = Roboflow(api_key="r4B2GUKhXPMna1hpLtMs")
project = rf.workspace("mustsmartproctor").project("must_proctor_final")
version = project.version(2)
dataset = version.download("yolov8")

from ultralytics import YOLO

model = YOLO('yolov8n.pt')

# 开始跑 50 轮
model.train(data=f'{dataset.location}/data.yaml', epochs=50, imgsz=640)
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to MUST_Proctor_Final-2 in yolov8:: 100%|██████████| 972/972 [00:00<00:00, 8006.85it/s]
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
